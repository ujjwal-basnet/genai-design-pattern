# %% [markdown]
# ## ** Practice ***

# %% [markdown]
# ### masking out continuations thata does't fit genration goals

# %%
from transformers import pipeline
MODEL_ID="Qwen/Qwen2.5-0.5B-Instruct"
pipe = pipeline("text-generation", model="Qwen/Qwen2.5-0.5B-Instruct", device_map="auto")
# Out:
# Device set to use cpu

# %%
classifier= pipeline(task='sentiment-analysis',MODEL_ID)
# Out:
# Some weights of Qwen2ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen2.5-0.5B-Instruct and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cuda:0

# %%
classifier(" classifiy the sentiment to postivie and negative : i am  felling happy")
# Out:
# [{'label': 'LABEL_0', 'score': 0.9987257122993469}]

# %%
classifier = pipeline('sentiment-analysis', MODEL_ID)
result = classifier("""I am learning a lot of neat concepts
from the
GenAI design patterns book.
""")
# Out:
# Some weights of Qwen2ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen2.5-0.5B-Instruct and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cuda:0

# %%
class MyRulesLogitsProcessor(LogitsProcessor):
    pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 class MyRulesLogitsProcessor(LogitsProcessor):
#       2     pass
#
# NameError: name 'LogitsProcessor' is not defined
